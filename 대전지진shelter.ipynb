# %%
#데이터 입력 프로그램

import pymysql

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""
sql=""

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()

print("추가할 데이터를 입력해주세요 : ")
while(True):
    print("(입력을 중단할 경우(facility ==> quit))")
    data1=input("facility ==> ")
    if data1=="quit":
        break;
    data2=input("f_name(필수항목)==> ")
    if data2 == "":
        break;
    data3=input("address ==> ")
    data4=input("area ==> ")
    data5=input("contact_num ==> ")
    sql=" REPLACE INTO sheltertbl1 VALUES('"+data1+"','"+data2+"','"+data3+"','"+data4+"','"+data5+"')"
    cur.execute(sql)
    

conn.commit()
conn.close()

# %%
#전체조회 예제(입력됐는지 확인해보기)
import pymysql
conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')

cur=conn.cursor(pymysql.cursors.DictCursor)
sql="SELECT * FROM sheltertbl1;"
cur.execute(sql)
result=cur.fetchall()
result

# %%
#데이터 전체 조회 프로그램
import pymysql

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""
row=None

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()

cur.execute("SELECT * FROM sheltertbl1;")

print("faility                          f_name                               address                  area                 contact_num")
print("-------------------------------------------------------------------------------------------------------------------------------")
            

while(True):
        row=cur.fetchone()
        if row== None:
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

conn.close()

# %%
#조건 검색 프로그램
import pymysql

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""
row=None

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()

print("무엇을 기준으로 검색하시겠습니까? (시설종류/시설명/주소/면적/연락처)")
con = input("> ")

#조건검색1: 시설종류
if con == '시설종류':
    print("\n검색할 '시설종류'를 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE facility = '{}'".format(con2)
    cur.execute(sql)    
    
#조건검색2: 시설명
elif con == '시설명':
    print("\n검색할 '시설명'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(con2)
    cur.execute(sql)

#조건검색3: 주소
elif con == '주소':
    print("\n검색할 '주소'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE address = '{}'".format(con2)
    cur.execute(sql)
        
#조건검색4: 면적
elif con == '면적':
    print("\n검색할 '면적 범위'을 입력해 주세요.")
    print("\n1)5,000이하")
    print("\n2)5,000~10,000")
    print("\n3)10,000~15,000")
    print("\n4)15,000~20,000")
    print("\n5)2,0000이상")
    con2 = input("> ")
    if(con2==1):
        sql="SELECT * FROM sheltertbl1 WHERE area BETWEEN '0' AND '5000'"
        cur.execute(sql)
    elif(con2==2):
        sql="SELECT * FROM sheltertbl1 WHERE area BETWEEN '5000' AND '10000'"
        cur.execute(sql)
    elif(con2==3):
        sql="SELECT * FROM sheltertbl1 WHERE area BETWEEN '10000' AND '15000'"
        cur.execute(sql)
    elif(con2==4):
        sql="SELECT * FROM sheltertbl1 WHERE area BETWEEN '15000' AND '20000'"
        cur.execute(sql)
    elif(con2==5):
        sql="SELECT * FROM sheltertbl1 WHERE area BETWEEN '20000' AND '100000'"
        cur.execute(sql)
       
    
#조건검색5: 연락처
elif con == '연락처':
    print("\n검색할 '연락처'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE contact_num = '{}'".format(con2)
    cur.execute(sql)
            
print("faility                          f_name                               address                  area                 contact_num")
print("-------------------------------------------------------------------------------------------------------------------------------")    
while(True):
    row=cur.fetchone()
    if row== None:
        print("*더 이상 일치하는 정보가 없습니다.")
        break
    data1=row[0]
    data2=row[1]
    data3=row[2]
    data4=row[3]
    data5=row[4]
    print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

conn.close()

# %%
#조건 검색 프로그램222(면적x)
import pymysql

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""
row=None

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()

print("무엇을 기준으로 검색하시겠습니까? (시설종류/시설명/주소/연락처)")
con = input("> ")

#조건검색1: 시설종류
if con == '시설종류':
    print("\n검색할 '시설종류'를 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE facility = '{}'".format(con2)
    cur.execute(sql)      
    
#조건검색2: 시설명
elif con == '시설명':
    print("\n검색할 '시설명'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(con2)
    cur.execute(sql)

#조건검색3: 주소
elif con == '주소':
    print("\n검색할 '주소'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE address LIKE concat('con2','%')"
    cur.execute(sql)
        

#조건검색5: 연락처
elif con == '연락처':
    print("\n검색할 '연락처'을 입력해 주세요.")
    con2 = input("> ")
    sql = "SELECT * FROM sheltertbl1 WHERE contact_num = '{}'".format(con2)
    cur.execute(sql)
            
print("faility                          f_name                               address                  area                 contact_num")
print("-------------------------------------------------------------------------------------------------------------------------------")    
while(True):
    row=cur.fetchone()
    if row== None:
        print("*더 이상 일치하는 정보가 없습니다.")
        break
    data1=row[0]
    data2=row[1]
    data3=row[2]
    data4=row[3]
    data5=row[4]
    print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

conn.close()

# %%
# 전체 프로그램
import pymysql

#조회 동작 
def fun1():
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    cur.execute("SELECT * FROM sheltertbl1;")
    
    print("faility                          f_name                               address                  area                 contact_num")
    print("-------------------------------------------------------------------------------------------------------------------------------")
            

    while(True):
        row=cur.fetchone()
        if row== None:
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))
    
    conn.close()

#추가 동작 완료
def fun2(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    data1,data2,data3,data4,data5="","","","",""
    while(True):
        print("추가할 데이터를 입력하세요 (입력을 중단할 경우 facility ==> quit 입력)")
        data1=input("facility ==> ")
        if data1=="quit":
            print('! 입력이 중단되었습니다.')
            break
        data2=input("f_name(필수항목) ==> ")
        if data2 == "":
            print('! 입력이 중단되었습니다.')
            break
        data3=input("address ==> ")
        data4=input("area ==> ")
        data5=input("contact_num ==> ")
        sql=" REPLACE INTO sheltertbl1 VALUES('"+data1+"','"+data2+"','"+data3+"','"+data4+"','"+data5+"')"
        cur.execute(sql)
        print("해당 데이터가 추가되었습니다.\n")
    conn.commit()
    conn.close()

#삭제 동작 완료
def fun3(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print("**대피소 삭제는 대피소의 이름을  통해서만 가능합니다 (삭제를 중단할 경우 quit 입력)**")
        print("삭제할 대피소의 이름을 입력하세요.")
        name=input(">")
        if name=="quit":
            print('! 삭제가 중단되었습니다.')
            break   
        sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(name)
        cur.execute(sql)
        row=cur.fetchone()
        if row== None:
            print("! 해당 대피소는 존재하지 않습니다.\n")
        else:
            sql="DELETE FROM sheltertbl1 WHERE f_name='{}'".format(name)
            cur.execute(sql)
            conn.commit()
            conn.close()
            print("해당 데이터가 삭제되었습니다.\n")

#검색 동작 
def fun4(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    print("검색")
    conn.close()
    
#수정 동작 완료
def fun5(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print('--------------------------------------------')
        print("정보를 수정할 대피소의 선택은 대피소의 이름을 통해서만 가능합니다(수정을 중단할 경우 quit를 입력하세요)")
        print("목록에서 수정할 대피소의 이름을 입력하세요.")
        f_name=input(">")
        print('--------------------------------------------')
        if f_name=="quit":
            print('! 수정이 중단되었습니다.')
            break
        else:
            sql="SELECT * FROM sheltertbl1 WHERE f_name='{}'".format(f_name)
            cur.execute(sql)
            row=cur.fetchone()
            if row== None:
                print("! 해당 대피소는 존재하지 않습니다.\n")
            else:
                con=input("\n어떤 정보를 수정하시겠습니까?(시설/주소/면적/전화번호)")
                if con=='시설':
                    print("시설을 무엇으로 수정하시겠습니까?")
                    new_facility=input(">")
                    sql="UPDATE sheltertbl1 SET facility='{}' WHERE f_name='{}'".format(new_facility,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='주소':
                    print("주소를 무엇으로 수정하시겠습니까?")
                    new_address=input(">")
                    sql="UPDATE sheltertbl1 SET address='{}' WHERE f_name='{}'".format(new_address,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='면적':
                    print("면적을 무엇으로 수정하시겠습니까?")
                    new_area=input(">")
                    sql="UPDATE sheltertbl1 SET area='{}' WHERE f_name='{}'".format(new_area,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='전화번호':
                    print("전화번호를  무엇으로 수정하시겠습니까?")
                    new_contact_num=input(">")
                    sql="UPDATE sheltertbl1 SET contact_num='{}' WHERE f_name='{}'".format(new_contact_num,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                else:
                    print("! 잘못된 정보를 입력하셨습니다. 다시 입력해주세요.\n")  
    conn.close()

while(True): #메인 루프 완료
    print('---------------------------------------------------------')
    print('  1. 조회    ')
    print('  2. 추가    ')
    print('  3. 삭제    ')
    print('  4. 검색    ')
    print('  5. 수정    ')
    print('  6. 종료    ')
    num = int(input('\n => 원하는 항목의 번호를 입력하세요(1 ~ 6) : '))
    print('---------------------------------------------------------')
    if num==6:
        print('종료')
        break
    elif num==1:
        fun1()
    elif num==2:
        fun2()
    elif num==3:
        fun3()
    elif num==4:
        fun4()
    elif num==5:
        fun5()
    else:
        print('\n ! 잘못된 번호입니다. 다시 선택해주세요.\n')

# %%
#조건 검색 프로그램222(면적x)
import pymysql

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""
row=None

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()
while(True):
    print("무엇을 기준으로 검색하시겠습니까? (시설종류/시설명/주소/연락처)")
    con = input("> ")

    #조건검색1: 시설종류
    if con == '시설종류':
        print("\n검색할 '시설종류'를 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE facility = '{}'".format(con2)
        cur.execute(sql) 
        while(True):
            row=cur.fetchone()
            if row== None:
                print("*더 이상 일치하는 정보가 없습니다.")
                break
            data1=row[0]
            data2=row[1]
            data3=row[2]
            data4=row[3]
            data5=row[4]
            print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

    #조건검색2: 시설명
    elif con == '시설명':
        print("\n검색할 '시설명'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(con2)
        cur.execute(sql)
        print("facility                          f_name                               address                  area                 contact_num")
        print("-------------------------------------------------------------------------------------------------------------------------------")
        row=cur.fetchone()
        if row== None:
            print("*더 이상 일치하는 정보가 없습니다.")
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

    #조건검색3: 주소
    elif con == '주소':
        print("\n검색할 '주소'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE address LIKE CONCAT('%','{}','%')".format(con2)
        cur.execute(sql)
        print("facility                          f_name                               address                  area                 contact_num")
        print("-------------------------------------------------------------------------------------------------------------------------------")
        row=cur.fetchone()
        if row== None:
            print("*더 이상 일치하는 정보가 없습니다.")
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))


    #조건검색5: 연락처
    elif con == '연락처':
        print("\n검색할 '연락처'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE contact_num = '{}'".format(con2)
        cur.execute(sql)
        print("facility                          f_name                               address                  area                 contact_num")
        print("-------------------------------------------------------------------------------------------------------------------------------")
        row=cur.fetchone()
        if row== None:
            print("*더 이상 일치하는 정보가 없습니다.")
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

    else:
        print("\n 잘못된 기준을 입력하셨습니다. 다시 입력해주세요.")
    conn.close()

# %%
#검색까지 넣은 전체코드
# 전체 프로그램
import pymysql

#조회 동작 
def fun1():
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    cur.execute("SELECT * FROM sheltertbl1;")
    data1,data2,data3,data4,data5="","","","",""
    
    print("faility                          f_name                               address                  area                 contact_num")
    print("-------------------------------------------------------------------------------------------------------------------------------")
            

    while(True):
        row=cur.fetchone()
        if row== None:
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))
    
    conn.close()

#추가 동작 완료
def fun2(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    data1,data2,data3,data4,data5="","","","",""
    while(True):
        print("추가할 데이터를 입력하세요 (입력을 중단할 경우 facility ==> quit 입력)")
        data1=input("facility ==> ")
        if data1=="quit":
            print('\n! 입력이 중단되었습니다.')
            break
        data2=input("f_name(필수항목) ==> ")
        if data2 == "":
            print('\n! 입력이 중단되었습니다.')
            break
        data3=input("address ==> ")
        data4=input("area(int) ==> ")
        data5=input("contact_num ==> ")
        sql=" REPLACE INTO sheltertbl1 VALUES('"+data1+"','"+data2+"','"+data3+"','"+data4+"','"+data5+"')"
        cur.execute(sql)
        print("해당 데이터가 추가되었습니다.\n")
    conn.commit()
    conn.close()

#삭제 동작 완료
def fun3(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print("**대피소 삭제는 대피소의 이름을  통해서만 가능합니다 (삭제를 중단할 경우 quit 입력)**")
        print("삭제할 대피소의 이름을 입력하세요.")
        name=input(">")
        if name=="quit":
            print('\n! 삭제가 중단되었습니다\n')
            break   
        sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(name)
        cur.execute(sql)
        row=cur.fetchone()
        if row== None:
            print("\n! 해당 대피소는 존재하지 않습니다.\n")
        else:
            sql="DELETE FROM sheltertbl1 WHERE f_name='{}'".format(name)
            cur.execute(sql)
            conn.commit()
            conn.close()
            print("해당 데이터가 삭제되었습니다.\n")

#검색 동작 
def fun4(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    print("무엇을 기준으로 검색하시겠습니까? (시설종류/시설명/주소/연락처)")
    con = input("> ")

    #조건검색1: 시설종류
    if con == '시설종류':
        print("\n검색할 '시설종류'를 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE facility = '{}'".format(con2)
        cur.execute(sql)      

    #조건검색2: 시설명
    elif con == '시설명':
        print("\n검색할 '시설명'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE f_name = '{}'".format(con2)
        cur.execute(sql)

    #조건검색3: 주소
    elif con == '주소':
        print("\n검색할 '주소'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE address LIKE CONCAT('%','{}','%')".format(con2)
        cur.execute(sql)


    #조건검색5: 연락처
    elif con == '연락처':
        print("\n검색할 '연락처'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl1 WHERE contact_num = '{}'".format(con2)
        cur.execute(sql)
    else:
        print("\n 잘못된 기준을 입력하셨습니다. - 오류 발생")

    print("faility                          f_name                               address                  area                 contact_num")
    print("-------------------------------------------------------------------------------------------------------------------------------")    
    while(True):
        row=cur.fetchone()
        if row== None:
            print("*더 이상 일치하는 정보가 없습니다.")
            break
        data1=row[0]
        data2=row[1]
        data3=row[2]
        data4=row[3]
        data5=row[4]
        print("%5s  %20s %35s  %15s  %18s" %(data1,data2,data3,data4,data5))

    conn.close()

    
#수정 동작 완료
def fun5(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print('--------------------------------------------')
        print("정보를 수정할 대피소의 선택은 대피소의 이름을 통해서만 가능합니다(수정을 중단할 경우 quit를 입력하세요)")
        print("목록에서 수정할 대피소의 이름을 입력하세요.")
        f_name=input(">")
        print('--------------------------------------------')
        if f_name=="quit":
            print('\n! 수정이 중단되었습니다.')
            break
        else:
            sql="SELECT * FROM sheltertbl1 WHERE f_name='{}'".format(f_name)
            cur.execute(sql)
            row=cur.fetchone()
            if row== None:
                print("\n! 해당 대피소는 존재하지 않습니다.\n")
            else:
                con=input("\n어떤 정보를 수정하시겠습니까?(시설/주소/면적/전화번호)")
                if con=='시설':
                    print("시설을 무엇으로 수정하시겠습니까?")
                    new_facility=input(">")
                    sql="UPDATE sheltertbl1 SET facility='{}' WHERE f_name='{}'".format(new_facility,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='주소':
                    print("주소를 무엇으로 수정하시겠습니까?")
                    new_address=input(">")
                    sql="UPDATE sheltertbl1 SET address='{}' WHERE f_name='{}'".format(new_address,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='면적':
                    print("면적을 무엇으로 수정하시겠습니까?")
                    new_area=input(">")
                    sql="UPDATE sheltertbl1 SET area='{}' WHERE f_name='{}'".format(new_area,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='전화번호':
                    print("전화번호를  무엇으로 수정하시겠습니까?")
                    new_contact_num=input(">")
                    sql="UPDATE sheltertbl1 SET contact_num='{}' WHERE f_name='{}'".format(new_contact_num,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                else:
                    print("\n! 잘못된 정보를 입력하셨습니다. 다시 입력해주세요.\n")  
    conn.close()

while(True): #메인 루프 완료
    print('---------------------------------------------------------')
    print('  1. 조회    ')
    print('  2. 추가    ')
    print('  3. 삭제    ')
    print('  4. 검색    ')
    print('  5. 수정    ')
    print('  6. 종료    ')
    num = int(input('\n => 원하는 항목의 번호를 입력하세요(1 ~ 6) : '))
    print('---------------------------------------------------------')
    if num==6:
        print('종료')
        break
    elif num==1:
        fun1()
    elif num==2:
        fun2()
    elif num==3:
        fun3()
    elif num==4:
        fun4()
    elif num==5:
        fun5()
    else:
        print('\n ! 잘못된 번호입니다. 다시 선택해주세요.\n')

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

conn,cur = None,None
conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur=conn.cursor()
cur.execute("SELECT * FROM sheltertbl1;")
data1,data2,data3,data4,data5="","","","",""
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)


result=cur.fetchall()
result=pd.DataFrame(result)
result.columns=["shelter", "f_name", "address", "area", "contact_num"]
result.rename(columns={"0":"shelter", "1":"f_name", "2":"address", "3":"area", "4":"contact_num"}, inplace=True)
result

# %%
#검색까지 넣은 전체코드###########
# 전체 프로그램
import pymysql

#출력 함수
def print_r(result):
    print("\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    cnames = ['시설명                           ', '시설이름                               ', '주소                                     ', '면적                 ','연락처                  ']
    for c in cnames:
        print(c.ljust(30, ' '), end='\t')
    print("\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    ccodes = ['facility', 'f_name', 'address', 'area', 'contact_num']
    for r in result:
        for c in ccodes:
            print(str(r[c]).ljust(30, ' '), end='\t')
        print("")
        print("-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")

#조회 동작 
def fun1():
    conn,cur = None,None
    data1,data2,data3,data4,data5="","","","",""

    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur = conn.cursor(pymysql.cursors.DictCursor)

    cur.execute("SELECT * FROM sheltertbl2")
    result=cur.fetchall()
    print_r(result)
    conn.close()

#추가 동작 완료
def fun2(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    data1,data2,data3,data4,data5="","","","",""
    while(True):
        print("추가할 데이터를 입력하세요 (입력을 중단할 경우 facility ==> quit 입력)")
        data1=input("facility ==> ")
        if data1=="quit":
            print('\n! 입력이 중단되었습니다.')
            break
        data2=input("f_name(필수항목) ==> ")
        if data2 == "":
            print('\n! 입력이 중단되었습니다.')
            break
        data3=input("address ==> ")
        data4=input("area(int) ==> ")
        data5=input("contact_num ==> ")
        sql=" REPLACE INTO sheltertbl2 VALUES('"+data1+"','"+data2+"','"+data3+"','"+data4+"','"+data5+"')"
        cur.execute(sql)
        print("해당 데이터가 추가되었습니다.\n")
    conn.commit()
    conn.close()

#삭제 동작 완료
def fun3(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print("**대피소 삭제는 대피소의 이름을  통해서만 가능합니다 (삭제를 중단할 경우 quit 입력)**")
        print("삭제할 대피소의 이름을 입력하세요.")
        name=input(">")
        if name=="quit":
            print('\n! 삭제가 중단되었습니다\n')
            break   
        sql = "SELECT * FROM sheltertbl2 WHERE f_name = '{}'".format(name)
        cur.execute(sql)
        row=cur.fetchone()
        if row== None:
            print("\n! 해당 대피소는 존재하지 않습니다.\n")
        else:
            sql="DELETE FROM sheltertbl2 WHERE f_name='{}'".format(name)
            cur.execute(sql)
            conn.commit()
            conn.close()
            print("해당 데이터가 삭제되었습니다.\n")

#검색 동작 
def fun4(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    print("무엇을 기준으로 검색하시겠습니까? (시설종류/시설명/주소/연락처)")
    con = input("> ")

    #조건검색1: 시설종류
    if con == '시설종류':
        print("\n검색할 '시설종류'를 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl2 WHERE facility = '{}'".format(con2)
        cur.execute(sql)      

    #조건검색2: 시설명
    elif con == '시설명':
        print("\n검색할 '시설명'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl2 WHERE f_name = '{}'".format(con2)
        cur.execute(sql)

    #조건검색3: 주소
    elif con == '주소':
        print("\n검색할 '주소'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl2 WHERE address LIKE CONCAT('%','{}','%')".format(con2)
        cur.execute(sql)


    #조건검색5: 연락처
    elif con == '연락처':
        print("\n검색할 '연락처'을 입력해 주세요.")
        con2 = input("> ")
        sql = "SELECT * FROM sheltertbl2 WHERE contact_num = '{}'".format(con2)
        cur.execute(sql)
    else:
        print("\n 잘못된 기준을 입력하셨습니다. - 오류 발생")

    cur.execute("SELECT * FROM sheltertbl2")
    result=cur.fetchall()
    print_r(result)

    conn.close()

    
#수정 동작 완료
def fun5(): 
    conn,cur = None,None
    conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
    cur=conn.cursor()
    while(True):
        print('--------------------------------------------')
        print("정보를 수정할 대피소의 선택은 대피소의 이름을 통해서만 가능합니다(수정을 중단할 경우 quit를 입력하세요)")
        print("목록에서 수정할 대피소의 이름을 입력하세요.")
        f_name=input(">")
        print('--------------------------------------------')
        if f_name=="quit":
            print('\n! 수정이 중단되었습니다.')
            break
        else:
            sql="SELECT * FROM sheltertbl2 WHERE f_name='{}'".format(f_name)
            cur.execute(sql)
            row=cur.fetchone()
            if row== None:
                print("\n! 해당 대피소는 존재하지 않습니다.\n")
            else:
                con=input("\n어떤 정보를 수정하시겠습니까?(시설/주소/면적/전화번호)")
                if con=='시설':
                    print("시설을 무엇으로 수정하시겠습니까?")
                    new_facility=input(">")
                    sql="UPDATE sheltertbl2 SET facility='{}' WHERE f_name='{}'".format(new_facility,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='주소':
                    print("주소를 무엇으로 수정하시겠습니까?")
                    new_address=input(">")
                    sql="UPDATE sheltertbl2 SET address='{}' WHERE f_name='{}'".format(new_address,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='면적':
                    print("면적을 무엇으로 수정하시겠습니까?")
                    new_area=input(">")
                    sql="UPDATE sheltertbl2 SET area='{}' WHERE f_name='{}'".format(new_area,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                elif con=='전화번호':
                    print("전화번호를  무엇으로 수정하시겠습니까?")
                    new_contact_num=input(">")
                    sql="UPDATE sheltertbl2 SET contact_num='{}' WHERE f_name='{}'".format(new_contact_num,f_name)
                    cur.execute(sql)
                    conn.commit()
                    print("\n해당 데이터가 수정되었습니다.")

                else:
                    print("\n! 잘못된 정보를 입력하셨습니다. 다시 입력해주세요.\n")  
    conn.close()

while(True): #메인 루프 완료
    print('---------------------------------------------------------')
    print('  1. 조회    ')
    print('  2. 추가    ')
    print('  3. 삭제    ')
    print('  4. 검색    ')
    print('  5. 수정    ')
    print('  6. 종료    ')
    num = int(input('\n => 원하는 항목의 번호를 입력하세요(1 ~ 6) : '))
    print('---------------------------------------------------------')
    if num==6:
        print('종료')
        break
    elif num==1:
        fun1()
    elif num==2:
        fun2()
    elif num==3:
        fun3()
    elif num==4:
        fun4()
    elif num==5:
        fun5()
    else:
        print('\n ! 잘못된 번호입니다. 다시 선택해주세요.\n')
# Out:
# ---------------------------------------------------------
#   1. 조회
#   2. 추가
#   3. 삭제
#   4. 검색
#   5. 수정
#   6. 종료
#
#  => 원하는 항목의 번호를 입력하세요(1 ~ 6) : 1
# ---------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 시설명                           	시설이름                               	주소                                     	면적                            	연락처
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 학교운동장                         	가수원중학교                        	대전광역시 서구 가수원로 26 (가수원동)       	3687                          	042-541-0145
# ...

# %%
#데이터 전체 조회 프로그램(다시보기)
import pymysql

def print_result(result):
    print("\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    cnames = ['시설명                           ', '시설이름                               ', '주소                                     ', '면적                 ','연락처                  ']
    for c in cnames:
        print(c.ljust(30, ' '), end='\t')
    print("\n---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")
    ccodes = ['facility', 'f_name', 'address', 'area', 'contact_num']
    for r in result:
        for c in ccodes:
            print(str(r[c]).ljust(30, ' '), end='\t')
        print("")
        print("-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------")

conn,cur = None,None
data1,data2,data3,data4,data5="","","","",""

conn=pymysql.connect(host='127.0.0.1', user='root', password='gyfdldid!16',db='shelterdb', charset='utf8')
cur = conn.cursor(pymysql.cursors.DictCursor)

cur.execute("SELECT * FROM sheltertbl2")
result=cur.fetchall()
print_result(result)
# Out:
# -----------------------------------------------------------------------------------------------------------------------
# 시설명           	시설이름           	주소                   	면적                	연락처
# -----------------------------------------------------------------------------------------------------------------------
# 학교운동장               	가수원중학교              	대전광역시 서구 가수원로 26 (가수원동)	3687                	042-541-0145
# ---------------------------------------------------------------------------------------------------------------------
# 학교운동장               	가수원초등학교             	대전광역시 서구 벌곡로 1359 (가수원동)	9914                	042-541-1334
# ---------------------------------------------------------------------------------------------------------------------
# 학교운동장               	가양중학교               	대전광역시 동구 비래서로62번길 100 (가양동)	11919               	042-620-1500
# ---------------------------------------------------------------------------------------------------------------------
# ...
